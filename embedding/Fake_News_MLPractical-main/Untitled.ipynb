# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('data/CategorisedFakeNewsTweetsFinal.csv')
#remove all meta-data features as we are comparing structure (except hashtags)
#compare to original data performance on baseline models

data.head()
# Out:
#    docID  majorityTarget                                          statement  \
# 0      0            True  End of eviction moratorium means millions of A...
# 1      1            True  End of eviction moratorium means millions of A...
# 2      2            True  End of eviction moratorium means millions of A...
# 3      3            True  End of eviction moratorium means millions of A...
# 4      4            True  End of eviction moratorium means millions of A...
#
#    binaryNumTarget                                              tweet  \
# 0              1.0  @POTUS Biden Blunders - 6 Month Update\n\nInfl...
# 1              1.0  @S0SickRick @Stairmaster_ @6d6f636869 Not as m...
# 2              1.0  THE SUPREME COURT is siding with super rich pr...
# 3              1.0  @POTUS Biden Blunders\n\nBroken campaign promi...
# 4              1.0  @OhComfy I agree. The confluence of events rig...
#
#   threeLabelMajority fiveLabelMajority primaryCat  primaryCatNum  \
# 0       Mostly Agree             Agree   Services              3
# 1        NO MAJORITY             Agree   Services              3
# 2              Agree             Agree   Services              3
# 3       Mostly Agree             Agree   Services              3
# 4              Agree             Agree   Services              3
#
#         secondaryCat  ...  determiners  conjunctions  dots  exclamation  \
# 0  Housing, Politics  ...            0             0     5            0
# 1  Housing, Politics  ...            0             2     1            0
# 2  Housing, Politics  ...            0             1     0            0
# 3  Housing, Politics  ...            0             1     3            0
# 4  Housing, Politics  ...            0             1     3            0
#
#    questions  ampersand  capitals  digits  long_word_freq  short_word_freq
# 0          1          0        33       3               5               19
# 1          0          0        14       0               2               34
# 2          0          0         3       0               4               10
# 3          0          1         6       8               1               30
# 4          1          0        11       3               2               19
#
# [5 rows x 54 columns]
